# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# Привет еще раз. Я буду также выделять свои комментарии цветом, но сейчас они будут отмечены так
#
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# Спасибо за доработку. Проект принят. Желаю удачи в дальнейшем обучении.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Татьяна, привет!👋</b>
#
# Меня зовут Горбунова Анастасия, и я буду давать обратную связь по твоему проекту. Предлагаю общаться на "ты", но если это  неудобно, обязательно скажи об этом, и мы перейдем на "вы"! Моя основная задача - поделиться своим опытом и помочь тебе пройти путь до аналитика данных.
#
# Чтобы тебе проще было ориентироваться, мои комментарии будут отмечены <font color='green'>👍 зеленым</font>, <font color='Orange'>💡 желтым</font> и <font color='red'>❌ красным</font> цветами:
#
#
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично! 👍:</b>
#
# Таким цветом отмечены правильные и удачные решения, на которые можно опираться в будущих проектах.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые рекомендации 💡:</b>
#
# Так отмечены комментарии-рекомендации на будущее или небольшие коррективы. Ты можешь учесть эти комментарии при выполнении следующих проектов.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Красным цветом отмечены комментарии, которые требуют твоего внимания. Решение на этом этапе требует переработки или внесения правок. После доработки проект будет принят.
# </div>
#
#
# В случае доработки проекта оставь все предыдущие комментарии без изменения. Пожалуйста, не удаляй, не перемещай и не изменяй мои комментарии. Это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
# Также прошу реагировать на мои комментарии своими: если ты что-то меняешь в проекте по моим рекомендациям - пиши об этом в ячейке Markdown. Выдели свои комментарии каким-либо другим заметным цветом, явно  отличающимся от цвета моих комментариев. Это нужно, чтобы не создавалась путаница и было проще отследить изменения.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Это шаблон для тебя, можешь воспользоваться им или сделать по своему усмотрению. Так я смогу быстро найти твои комментарии.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h3> Комментарий ревьюера <a class="tocSkip"> </h3>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Спасибо, что есть оглавление. Так по проекту удобно перемещаться.
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# Описание данных:

# %% [markdown]
# • airports_nearest — расстояние до ближайшего аэропорта (м)<br>
# • balcony — число балконов<br>
# • ceiling_height — высота потолков (м)<br>
# • cityCenters_nearest — расстояние до центра города (м)<br>
# • days_exposition — сколько дней было размещено объявление (от публикации до снятия)<br>
# • first_day_exposition — дата публикации<br>
# • floor — этаж<br>
# • floors_total — всего этажей в доме<br>
# • is_apartment — апартаменты (булев тип)<br>
# • kitchen_area — площадь кухни в квадратных метрах (м²)<br>
# • last_price — цена на момент снятия с публикации<br>
# • living_area — жилая площадь в квадратных метрах (м²)<br>
# • locality_name — название населённого пункта<br>
# • open_plan — свободная планировка (булев тип)<br>
# • parks_around3000 — число парков в радиусе 3 км<br>
# • parks_nearest — расстояние до ближайшего парка (м)<br>
# • ponds_around3000 — число водоёмов в радиусе 3 км<br>
# • ponds_nearest — расстояние до ближайшего водоёма (м)<br>
# • rooms — число комнат<br>
# • studio — квартира-студия (булев тип)<br>
# • total_area — площадь квартиры в квадратных метрах (м²)<br>
# • total_images — число фотографий квартиры в объявлении<br>

# %% [markdown]
# Пояснение: апартаменты — это нежилые помещения, которые не относятся к жилому фонду, но имеют необходимые условия для проживания.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h3> Комментарий ревьюера <a class="tocSkip"> </h3>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
#
# Здорово, что есть вступление к твоему проекту. Так получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt # импорт библиотеки для создания графиков
from pandas.plotting import scatter_matrix

# %%
try:
    df = pd.read_csv(r'C:\Users\tanch\Desktop\data science\проекты\Исследовательский анализ данных\real_estate_data.csv', sep='\t') # чтение файла с данными
except:
    df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
df.head(10) # просмотр первых 10 строк таблицы
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h3> Комментарий ревьюера <a class="tocSkip"> </h3>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Еще можно использовать стандартную библиотеку ``os``:
#
# https://pythonworld.ru/moduli/modul-os.html
#
# </div>

# %%
df.info() # получение информации о данных в таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Плюс за использование метода info.describe()😎 С помощью него достаточно быстро можно получить информацию о статистических показателях.
#
# </div>

# %% [markdown]
# По результатам работы методов info() и describe():
# 22 колонки, 23699 записей.
# Анализ столбцов:
#  - "total_images" (число фотографий квартиры в объявлении) без пропусков. Минимальное значение - 0, возможно просто нет фото, максимальное - 50 (очень много, но вполне вероятно). Оставим без изменений;
#  - "last_price" (цена на момент снятия с публикации) - пропусков нет, переведем в int, для удобства восприятия;
#  - "total_area" (площадь квартиры, м2) без пропусков, однако большая разница в значениях, дополнительный анализ;
#  - "first_day_exposition" (дата публикации), без пропусков, перевести из формата object в формат времени datetime;
#  - "rooms" (число комнат) без пропусков, но есть миниальное значение - 0, и максимальное - 19, дополнительный анализ;
#  - "ceiling_height" (высота потолков, м) есть пропуски и большой диапазон значений, дополнительный анализ;
#  - "living_area" (жилая площадь, м2), пропуски, разбег по значениям, дополнительный анализ;
#  - "floor" (этаж), пропусков нет, формат корректный, оставим без изменений;
#  - "floors_total" (всего этажей в доме)незначительные пропуски, сменим формат на int;
#  - "is_apartment" (апартаменты), очень много пропусков, по условиям проекта изменим на тип данных bool;
#  - "studio" (квартира-студия), пропусков нет, тип данных bool, оставим без изменений;
#  - "open_plan" (свободная планировка), пропусков нет, тип данных bool, оставим без изменений;
#  - "kitchen_area" (площадь кухни, м2), пропуски, большой размах значений, дополнительный анализ;
#  - "balcony" (число балконов), пропуски, перевести в формат int;
#  - "locality_name" (название населенного пункта), незначительные пропуски, исправить;
#  - "airports_nearest" (расстояние до ближайшего аэропорта, м) есть пропуски, перевести в формат int;
#  - "cityCenters_nearest" (расстояние до центра города), пропуски, дополнительный анализ;
#  - "parks_around3000" (число парков радиусе 3 км) переведем в "змеиный регистр", пропуски, перевести в формат int;
#  - "parks_nearest" (расстояние до ближайшего парка, м), пропуски, перевести в формат int;
#  - "ponds_around3000" число водоемов в радиусе 3 км) аналогично "parks_around3000";
#  - "ponds_nearest" (расстояние до ближайшего водоема, м), аналогично "parks_nearest";
#  - "days_exposition" (сколько дней было размещено объявление от публикации до снятия) пропуски, перевести в формат int.

# %% [markdown]
# По результатам работы метода df.describe() нужно обратить внимание на минимальные и максимальные показатели (подключаем здравый смысл). Например, в столбце "ceiling_height" (высота потолков (м)) минимальное значение - 1 м (каморка Папы Карло?), а максимальное - 100 метров (ангар для самолетов?). Или в столбце "living_area" (жилая площадь в м2): минимальная 2 м2 (точно каморка Папы Карло!?), а максимальная более 400 м2 (особняк?). Необходимо проанализировать каждый столбец.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 😎 Хороший вывод. Когда есть краткий обзор, понятнее становятся шаги на следуюющем этапе.
#
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Прежде, чем приступить к обработке данных исправим название столбцов "parks_around3000", "ponds_around3000" и "cityCenters_nearest"

# %%
# столбцы "parks_around3000" и "ponds_around3000" переведем в "змеиный регистр" для удобства восприятия 
df = df.rename(columns={'parks_around3000' : 'parks_around_3000', 'ponds_around3000' : 'ponds_around_3000', 'cityCenters_nearest' : 'city_centers_nearest'})

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Обрати внимание, что столбец cityCenters_nearest тоже написан стилем сamelCase. Можно привести название и этой колонки в единый формат snake_case, для однообразного отображения.
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Спасибо, что обратила внимание! Исправила!
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 👍
#
# </div>

# %% [markdown]
# И переведем столбец "first_day_exposition" (дата публикации) в корректный формат времени

# %%
# преобразуем столбец "first_day_exposition" (дата публикации) в формат времени datetime
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Промежуточная проверка

# %%
df.info() # получение информации о данных в таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %%
df.head() # просмотр первых 5 строк таблицы
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Исправлены регистры для столбцов "parks_around3000" и "ponds_around3000", а также установлен корректный формат данных для столбца "first_day_exposition".

# %% [markdown]
# Опеределим столбцы и количество строк с пропусками данных, а также процент пропусков:

# %%
display(df.isna().sum()) #количество пропусков
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
display(df.isna().mean() * 100) #процент пропусков
# Out:
# total_images             0.000000
# last_price               0.000000
# total_area               0.000000
# first_day_exposition     0.000000
# rooms                    0.000000
# ceiling_height          38.799105
# floors_total             0.362885
# living_area              8.029875
# floor                    0.000000
# is_apartment            88.290645
# studio                   0.000000
# open_plan                0.000000
# kitchen_area             9.612220
# balcony                 48.605426
# locality_name            0.206760
# airports_nearest        23.384953
# city_centers_nearest    23.287902
# parks_around_3000       23.283683
# parks_nearest           65.909954
# ponds_around_3000       23.283683
# ponds_nearest           61.559559
# days_exposition         13.422507
# dtype: float64

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Удобное представление количества пропусков.

# %% [markdown]
# Более половины столбцов таблицы содержат пропуски значений. Для каждого столбца будем находить оптимальный вариант для заполнения пропусков.

# %% [markdown]
# Столбец "total_images" можно исключить из анализа, т.к. количество фотографий ни как не повлияет на результат исследования.

# %% [markdown]
# Значения в столбцах о наличие и расстоянии до парков и прудов ("parks_around_3000", "ponds_around_3000", "parks_nearest" и "ponds_nearest"), а также столбец "airports_nearest" (расстояние до ближайщего аэропорта) не вкkючены в исследование. Поэтому заменим на нули или на экстремальные значения и переведем в формат int:

# %%
# исправляем количество парков 
df['parks_around_3000'] = df['parks_around_3000'].fillna(value=0)
df['parks_around_3000'] = df['parks_around_3000'].astype('int')
# исправляем количество прудов
df['ponds_around_3000'] = df['ponds_around_3000'].fillna(value=0)
df['ponds_around_3000'] = df['ponds_around_3000'].astype('int')

# %% [markdown]
# Аналогично поступим со столбцами "parks_nearest" и "ponds_nearest"

# %%
# исправляем расстояние до парка 
df['parks_nearest'] = df['parks_nearest'].fillna(value=0)
df['parks_nearest'] = df['parks_nearest'].astype('int')
# исправляем расстояние до пруда
df['ponds_nearest'] = df['ponds_nearest'].fillna(value=0)
df['ponds_nearest'] = df['ponds_nearest'].astype('int')

# %% [markdown]
# И со столбцом "airports_nearest":

# %%
# исправляем расстояние до аэропорта 
df['airports_nearest'] = df['airports_nearest'].fillna(value=-9999)
df['airports_nearest'] = df['airports_nearest'].astype('int')

# %% [markdown]
# Столбец "last_price" без пропусков, сменим тип данных с float64 на int:

# %%
df['last_price'] = df['last_price'].astype('int') # меняем формат на int

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошо.

# %% [markdown]
# Начнем с очевидных пропусков. В столбце "balcony" (число балконов) 11519 пропусков. Скорее всего, при заполнении их не указали, т.к. просто балконов нет. Заполним пропуски нулями. Так же изменим формат с float64 на целочисленный:

# %%
# исправляем столбец "balcony" (число балконов):
df['balcony'] = df['balcony'].fillna(0) # заполняем пропуски нулями 
df['balcony'] = df['balcony'].astype('int') # меняем формат на int

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Логичная замена.

# %% [markdown]
# Столбец "locality_name" (название населенного пункта) 49 пропусков. Возможные причины в пропусках как человеческий фактор (не указал, пропустил), так и сбой во время сбора данных. В любом случае, количество пропусков очень незначительно (0,2%), да и нет привязки к местности,  поэтому удалим эти строки из датасета:

# %%
# исправляем "locality_name" (название населенного пункта):
df = df.dropna(subset=['locality_name']).reset_index(drop=True) # удаляем пропуски и заново переписываем индексы таблицы

# %% [markdown]
# Для столбца "floors_total" (всего этажей в доме) 0,36% пропусков. Количество не велико, можно удалить. Так же заменим тип данных с float64 на целочисленный:

# %%
df = df.dropna(subset=['floors_total']).reset_index(drop=True) # удаляем пропуски, обновляем индексы
df['floors_total'] = df['floors_total'].astype('int') # меняем формат на int

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Удалить пропуски в этих данных - верное решение, т.к. доля пропусков мала.
#
# </div>

# %% [markdown]
# Согласно пояснению к проекту: аппартаменты - это нежилые помещения, которые не относятся к жилому фонду, но имеют необходимые условия для проживания. Поэтому для столбца "is_apartment" заменим все пропуски на значение False, что будет соответствовать жилому фонду. Также сменим формат данных на bool:

# %%
df['is_apartment'] = df['is_apartment'].fillna(value=False)
df['is_apartment'] = df['is_apartment'].astype('bool')

# %%
df.info() # промежуточная проверка
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Остальные столбцы таблицы будем исследовать дополнительно, т.к. согласно методу describe() в данных есть значения, на которые стоит обратить внимание.

# %%
df['ceiling_height'].describe() # изучим информацию по столбцу "ceiling_height"
# Out:
# count    14481.000000
# mean         2.771283
# std          1.261983
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В столбце "ceiling_height" есть пропуски. Высота потолков имеет среднее значение 2,77 м. Из "экстремальных" показателей: 1 и 100 м.

# %% [markdown]
# Согласно СНиП в массовой типовой многоквартирной застройке высота потолков зависит от климатической зоны и не может быть ниже 2,5 м или 2,7 м. Все потолки, которые превосходят эти значения, можно считать высокими. Обычно называют высокими потолки от 3 м. В частном домостроении таких ограничений нет, архитектурные решения позволяют строить дома с высотой потолков до 5–6 м. Чаще всего такие расстояния делаются в строениях со вторым светом. <br>

# %% [markdown]
# Узнаем количество объявлений, высота потолков в которых больше или равно 4 м:

# %%
print(len(df[df['ceiling_height'] >= 4]))
# Out:
# 113

# %% [markdown]
# Сгруппируем потолки следующим образом:<br>
# - возьмем за максимальную высоту потолка - 4 м. Таких не много, на среднее значение сильного влияния не окажут.
# - в значениях, где высоты потолков от 25 м, скорее всего пропущена запятая. Поэтому, нужно просто поделить на 10, чтобы получить стандартную высоту потолка.
# - все пропуски и потолки, что ниже 2,5 м, а также выше 4 заполним медианными значениями по столбцу "ceiling_height".<br>
# Напишем функцию, которая исправит потолки выше 25 м:

# %%
def ceiling_height_fix(height): # исправляем высоту потолков, все что выше или равно 25 м 
    if height >= 25:
        return height / 10
    if height < 25:
        return height
df['ceiling_height'] = df['ceiling_height'].apply(ceiling_height_fix)

# %%
df['ceiling_height'].describe() # проверка работы функции
# Out:
# count    14481.000000
# mean         2.733465
# std          0.425788
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         24.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Функция отработала высокие потолки.

# %% [markdown]
# Вычисли медианные значения потолков в диапазон от 2,5 до 4 м. Для этого сделаем срез по датасет и применим метод median():

# %%
ceiling_height_median = df.query('ceiling_height >= 2.5 or  ceiling_height <= 4') # срез по датасету
median_height = ceiling_height_median['ceiling_height'].median() # медианное значение по срезу 
print(median_height) # просмотр результата среза
# Out:
# 2.65

# %% [markdown]
# Опеределили медианное значение. Заполним пропуски.

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(value=median_height) # заполняем пропуски

# %% [markdown]
# Напишем функцию, которая исправит потолки меньше 2,5 и больше 4 м и заполнит их найденным медианным значением:

# %%
def ceiling_height_fix_median(height): # исправляем высоту потолков, все что меньше 2,5 или выше 4 м 
    if height < 2.5 or height > 4:
        return median_height
    return height
df['ceiling_height'] = df['ceiling_height'].apply(ceiling_height_fix_median)

# %% [markdown]
# Проверим столбец "ceiling_height":

# %%
df['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.694123
# std          0.203614
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошее всосстановление данных.
#
# </div>

# %% [markdown]
# Результат:
# - пропусков нет;
# - минимальное и максимальное значение высот потолка соответсвует СНиП (2,5  и 4,0 м соответственно);
# - среднее значение 2,69 м.

# %% [markdown]
# Продолжаем анализировать данные датасета.

# %% [markdown]
# Столбцы "living_area" и "kitchen_area" содержат пропуски, 8,02% и 9,61% соответственно. Это довольно много, заполнение нулями может привести к искажению выводов.

# %% [markdown]
# Для столбца "living_area" (жилая площадь) выполним следующее:
# - сгруппируем по столбцу "rooms" и найдем по столбцу "living_area" среднюю жилую площадь для каждой группы;
# - заполним пропуски этими значениями.

# %%
print(df.groupby('rooms')['living_area'].median()) #просмотр медиальный значений для каждой группы (по количеству комнат)
# Out:
# rooms
# 0      18.000
# 1      17.600
# 2      30.500
# 3      45.000
# 4      63.650
# 5      91.785
# 6     124.400
# 7     145.000
# 8     161.000
# 9     179.200
# 10    161.400
# 11    133.900
# 12    409.700
# 14    195.150
# 15    409.000
# 16    180.000
# 19    264.500
# Name: living_area, dtype: float64

# %%
df['living_area'] = df['living_area'].fillna(df.groupby('rooms')['living_area'].transform('median'))

# %%
print(df['living_area'].isna().sum()) # узнаем сколько пропусков в столбце "living_area"
# Out:
# 0

# %% [markdown]
# Пропуски в столбце "living_area" отсутствуют. Заполняем пропуски в столбце "kitchen_area":

# %%
print(df.groupby('rooms')['kitchen_area'].median()) #просмотр медиальных значений для каждой группы (по количеству комнат)
# Out:
# rooms
# 0        NaN
# 1       9.00
# 2       8.70
# 3       9.50
# 4      11.00
# 5      15.10
# 6      19.75
# 7      20.00
# 8      25.00
# 9      14.30
# 10     19.80
# 11     12.60
# 12    112.00
# 14     21.25
# 15    100.00
# 16     13.00
# 19     27.60
# Name: kitchen_area, dtype: float64

# %% [markdown]
# В группе "rooms", где количество комнат указано ноль у нас пропуски. Возможно это квартиры-студии, где нет четкого разделения на зону кухни и жилой комнаты. Поэтому эту категорию не получится заполнить медианными значениями  по столбцу "rooms". Значит с этой группой поступим иначе, но сначала заполним пропуски в других группах:

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df.groupby('rooms')['kitchen_area'].transform('median'))

# %% [markdown]
# Основную часть пропусков заполнили. Узнаем сколько осталось пропусков в группе "rooms" равное "0" (квартиры-студии):

# %%
print(df['kitchen_area'].isna().sum()) # узнаем сколько пропусков в столбце "kitchen_area"
percent = df['kitchen_area'].isna().mean() #и процент пропусков в этом столбце
print(f'Процент пропусков: {percent:.2%}')
# Out:
# 194
# Процент пропусков: 0.82%

# %% [markdown]
# Всего 194 пропуска. Это 0,82%. Заполним нулями:

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(0)

# %%
print(df['kitchen_area'].isna().sum()) # проверка пропусков в столбце "kitchen_area"
# Out:
# 0

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Молодец.
#
# </div>

# %% [markdown]
# Изучим информацию о столбце "city_centers_nearest" (расстояние до центра города, м)

# %%
print(df['city_centers_nearest'].isna().sum()) # узнаем сколько пропусков в столбце "city_centers_nearest"
percent = df['city_centers_nearest'].isna().mean() #и процент пропусков в этом столбце
print(f'Процент пропусков: {percent:.2%}')
# Out:
# 5501
# Процент пропусков: 23.34%

# %% [markdown]
# По условию исследования проекта, необходимо изучить квартиры, находящиеся в центре Санкт-Петербурга. Узнаем, сколько пропущенных значений из столбца "city_centers_nearest" приходится на Санкт-Петербург:

# %%
query_SP = df.query('locality_name == "Санкт-Петербург"') # срез датасета по Санкт-Петербургу 
print(len(query_SP)) # количество строк среза
print(query_SP['city_centers_nearest'].isna().sum()) # пропуски в столбце "city_centers_nearest" по Санкт-Петербургу
percent = query_SP['city_centers_nearest'].isna().mean() #и процент пропусков в этом столбце
print(f'Процент пропусков: {percent:.2%}')
# Out:
# 15651
# 60
# Процент пропусков: 0.38%

# %% [markdown]
# Количество пропусков по нужному условию очень мал, поэтому заполним пропуски в столбце "city_centers_nearest" нулями. Это практически не повлияет на результат исследования.

# %%
df['city_centers_nearest'] = df['city_centers_nearest'].fillna(0)

# %% [markdown]
# Определим количество пропусков для "days_exposition" (сколько дней было размещено объявление от публикации до снятия).

# %%
print(df['days_exposition'].isna().sum()) # узнаем сколько пропусков в столбце "days_exposition"
percent = df['days_exposition'].isna().mean() #и процент пропусков в этом столбце
print(f'Процент пропусков: {percent:.2%}')
# Out:
# 3171
# Процент пропусков: 13.46%

# %% [markdown]
# Процент пропусков может повлиять на итоговый результат исследования. Проведем дополнительный анализ этого столбца. Для этого выполним замену пропусков нулями по всему столбцу, а также переведем в формат int. После этого сделаем группировку по столбцу "first_day_exposition", а точнее по году публикации объявления.

# %%
df['days_exposition'] = df['days_exposition'].fillna(0).astype('int')

#группировка по году публикации  
df_year = df.query('days_exposition == 0').groupby(by=df['first_day_exposition'].dt.year).count()
display(df_year)
# Out:
#                       total_images  last_price  total_area  \
# first_day_exposition
# 2014                            18          18          18
# 2015                            70          70          70
# 2016                            67          67          67
# 2017                           271         271         271
# 2018                           957         957         957
# 2019                          1788        1788        1788
#
#                       first_day_exposition  rooms  ceiling_height  \
# first_day_exposition
# 2014                                    18     18              18
# 2015                                    70     70              70
# 2016                                    67     67              67
# 2017                                   271    271             271
# 2018                                   957    957             957
# 2019                                  1788   1788            1788
#
# ...

# %% [markdown]
# В таблице представленны данные за 6 лет. В период с 2014-2016 гг. количество пропусков незначительное. Начиная с 2017 года наблюдается увеличение количества пропусков в столбце "days_exposition". Возможно это свяно с тем, что на момент, когда снимали данные, квартиры выставленные на продажу по факту еще не были проданы. Поэтому оставим эти пропуски без изменений.

# %% [markdown]
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
#
# <font color='red'><b>На доработку ❌:</b>  </font>
#
#
# Прежде, чем заполнять пропуски, необходимо убедиться, что эти данные пропущены случайно, По столбцу `days_exposition` - Мы можем заполнять только те данные, которые пропущенны совершенно случайно (MCAR). Иначе заполнение может повлиять на характер связи между заполняемой величиной и остальными. Стоит посмотреть на распределение пропусков во временном диапазоне (относительно года выставления недвижимости на продажу). Посмотри на взаимосвязь отсутствия даты закрытия продажи и года выставления. Может быть само наличие пропуска в этих данных несет смысл и лучше его оставить?  Сформулируй выводы. Пересмотри подход к обработке пропусков в данном столбце. Лучше их оставить без изменения.
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Постаралась исправить так, как поняла :)
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Верно, пропуски в этих данных означат, что квартиры еще не проданы.
#
# </div>

# %% [markdown]
# Проверим таблицу на наличие явных дубликатов:

# %%
print(df.duplicated().sum()) # явные дубликаты
# Out:
# 0

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Очень хорошо, что есть проверка на дубликаты. Про это легко забыть. А в некоторых исследованиях дубликаты могут серьезно исказить результаты.
#
#
# </div>

# %%
display(df.isna().sum()) # проверка на пропуски
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# city_centers_nearest    0
# parks_around_3000       0
# parks_nearest           0
# ponds_around_3000       0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %%
df.info() # просмотр результат предобработки
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Данные были изучены на наличие пропусков, а также соответствие типов данных содержимому столбцов таблицы. Для каждого столбца таблицы подобраны оптимальные способы заполнения пропусков и типы данных. Проверка на явные дубликаты. По результатам выполненной работы - пропусков в данных нет, типы исправлены, дубликатов нет.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Ты предложила определенные подходы к работе с пропусками в данных и выполнила замену типов данных там, где это было необходимо.  А также очень хорошо, что сделала контрольную проверку. В целом, очень хорошая и полная предобработка данных.
#
#
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Рассчитаем и добавим в таблицу цену за квадратный метр "price_sq_m". Переведем в формат int

# %%
df['price_sq_m'] = df['last_price'] / df['total_area'] # цена за квадратный метр
df['price_sq_m'] = df['price_sq_m'].astype('int')

# %% [markdown]
# Добавим в таблицу день, месяц и год публикации объявлений:

# %%
df['weekday_exposition'] = df['first_day_exposition'].dt.weekday # день публикации
df['montn_exposition'] = df['first_day_exposition'].dt.month # месяц публикации
df['year_exposition'] = df['first_day_exposition'].dt.year # год публикации

# %% [markdown]
# Создадим функцию, которая установит категорию этажа: первый, последний или другой. Функция сравнит этаж и всего этажей в доме, после присвоит нужную категорию.

# %%
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    if floor == floors_total:
        return 'последний'
    return 'другой'
df['floor_category'] = df.apply(floor_category, axis = 1)

# %% [markdown]
# Вычислим в столбец "ratio_living_total" соотношения жилой и общей площади:

# %%
df['ratio_living_total'] = df['living_area'] / df['total_area']

# %% [markdown]
# А также вычислим в столбец "ratio_kitchen_total" соотношения жилой и общей площади:

# %%
df['ratio_kitchen_total'] = df['kitchen_area'] / df['total_area']

# %% [markdown]
# Проверим итоговую таблицу

# %%
display(df.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         45.0      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  price_sq_m  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Вычисления верны.
#
#
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Изучим подробнее следующие параметры таблицы: площадь, цена, число комнат и высоту потолков.

# %%
df['total_area'].describe() # изучим информацию по столбцу "total_area"
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Столбец "total_area" (площадь квартиры, м2) без пропусков, однако максимальное значение - 900 м2. Для жилого фонда (квартиры) это очень большая площадь, возможно, что это площадь аппартаментов (нежилой фонд). Либо в процессе внесения данных ошибочно добавили ноль. Также нельзя исключать сбой.<br>
# Значение минимума в 12 м2 маловероятно, но возможно это студия. Для студий характерный очень малые размеры площади.

# %% [markdown]
# Построим гистограмму для столбца "total_area":

# %%
# строим гистограмму на 100 корзин, со значениями min и max из describe()
df['total_area'].plot(
    kind='hist',
    histtype='step',
    range=(12, 900),
    bins=100,
    linewidth=3,
    alpha=0.7,
    label='Площадь квартиры, м2',
    grid=True,
    legend=True,
    figsize=(10, 5)    
) 
plt.xlabel("Площадь квартиры")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "total_area"')
plt.show() # просмотр гистограммы

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Хорошо бы добавить подпись второй оси и название графика.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Добавила подпись оси и название графика
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошо.
#
# </div>

# %% [markdown]
# На гистограмме наблюдаются, что  в основном продаются квартиры с площадью от 30 до 200 м2. Причем, после показателя 200 м2 есть явные выбросы данных. Изучим более подробно пик гистограммы. Для этого рассмотрим значения от минимального до 200 и уменьшим количество корзин:

# %%
# строим гистограмму пика на 30 корзин
df['total_area'].plot(
    kind='hist',
    histtype='step',
    range=(12, 200),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Площадь квартиры, м2',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Площадь квартиры")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "total_area"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Максимальное количество объявлений - это квартиры, площадь которых до 75 м2. Потом наблюдается спад. В результате, квартиры с площадью более 125 м2 появляются в продаже гораздо реже, чем малогабаритные. Особо следует отметить, что квартиры от 30 до 50м2 наиболее распространнены.

# %% [markdown]
# Рассмотрим данные по площади квартир от 200 до максимального значения:

# %%
# строим гистограмму на 30 корзин, со значениями 200 и max из describe()
df['total_area'].plot(
    kind='hist',
    histtype='step',
    range=(200, 900),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Площадь квартиры, м2',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Площадь квартиры")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "total_area"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Видно, что количество объявлений о продаже квартир площадью больше 200 м2 уже редкость. Скорее всего это можно отнести к выбросам. На предыдущей гистограмме видно, что спад наблюдается уже после 125. Большая редкость квартиры с такими площадями. Возможно, это частные дома или квартиры, которые получились путем объединения нескольких квартир в одну. Так же надо, учитывать тот факт, что в таблице есть аппартаменты, возможно именно они влияют на такой размах по площади.

# %% [markdown]
# Определим, сколько всего объявлений, площадь которых превыщает 125 м2 являются аппартаментами:

# %%
df.query('total_area > 125 and is_apartment == True')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2748             11     7500000       152.0           2018-07-27      3
# 7483             16    43500000       245.8           2015-12-17      3
# 7977             20    84000000       507.0           2015-12-17      5
# 10334            18    30000000       137.0           2018-08-07      3
# 10807             1    56844500       177.9           2015-01-15      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2748             3.00             3         45.0      1          True  ...
# 7483             2.65             7        170.8      7          True  ...
# 7977             2.65             7        301.5      7          True  ...
# 10334            3.00             5         90.0      4          True  ...
# 10807            2.65             6         87.2      5          True  ...
#
#        ponds_around_3000  ponds_nearest  days_exposition  price_sq_m  \
# ...

# %% [markdown]
# Всего пять объявлений, площадь которых больше 125 м2 являются аппартаментами. Отсюда вывод, что все огромные площади относятся к жилому фонду.

# %%
# определяем жилые объекты с большой площадью и их местонахождение
total_area_big = df.query('total_area > 125 and is_apartment == False')
total_area_big.groupby('locality_name')['locality_name'].count()
# Out:
# locality_name
# Всеволожск                   1
# Выборг                       5
# Гатчина                      3
# Зеленогорск                  1
# Колпино                      2
# Красное Село                 2
# Кронштадт                    2
# Павловск                     2
# Петергоф                     4
# Пушкин                      18
# Санкт-Петербург            873
# Сертолово                    1
# Сестрорецк                   5
# Сосновый Бор                 1
# деревня Бор                  1
# деревня Кальтино             1
# деревня Новое Девяткино      2
# деревня Хязельки             1
# посёлок Александровская      1
# посёлок Парголово            1
# посёлок Репино               2
# посёлок Стрельна             2
# посёлок Шушары               1
# Name: locality_name, dtype: int64

# %% [markdown]
# 873 объекта недвижимости с площадью более 125 м2 находится в Санкт-Петербурге. Это вполне логично. Однако площади квартир более 200 м2 даже для такого города, маловероятны.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Молодец.
#
#
# </div>

# %% [markdown]
# Рассмотрим гистограммы из категории цена: "last_price" (цена на момент снятия публикации) и "price_sq_m" (цена за м2)

# %% [markdown]
# Для удобства восприятия цифр, переведем значения в столбце "last_price" из рублей в млн.руб

# %%
df['last_price'] = df['last_price'] / 1000000 # перевод их рублей в млн.руб.

# %%
df['last_price'].describe()
# Out:
# count    23565.000000
# mean         6.540058
# std         10.910935
# min          0.012190
# 25%          3.400000
# 50%          4.646000
# 75%          6.790000
# max        763.000000
# Name: last_price, dtype: float64

# %%
# строим гистограмму на 100 корзин, со значениями min и max из describe()
df['last_price'].plot(
    kind='hist',
    histtype='step',
    range=(0.012190, 763),
    bins=100,
    linewidth=3,
    alpha=0.7,
    label='Цена на момент снятия публикации',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Цена на момент снятия публикации")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "last_price"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Очень высокий пик на гистограмме. Видно, что после значения 50 млн.руб. график стремится к нулю. Рассмотрим подробнее диапазон от min до 50 млн.руб.

# %%
# строим гистограмму на 50 корзин, со значениями min и 50 млн.руб
df['last_price'].plot(
    kind='hist',
    histtype='step',
    range=(0.012190, 50),
    bins=50,
    linewidth=3,
    alpha=0.7,
    label='Цена на момент снятия публикации',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Цена на момент снятия публикации")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "last_price"')
plt.show() # просмотр гистограммы

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Простой способ избавить от е-формата чисел при анализе данного столбца - перевести значения в колонке last_price из руб в млн руб. Для этого значения в колонке last_price нужно разделить на 1 000 000.
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 👍
#
# </div>

# %% [markdown]
# Основной ценовой диапазон находится от 1 млн.руб до 10 млн.руб. Средний показатель около 7 млн.руб. Квартиры, цена которых более 10 млн. руб встречаются гораздо реже. Единичные предложения для квартир, стоимость которых более 15 млн.руб.

# %% [markdown]
# Изучим данные столбца "price_sq_m". Переведем значение из рублей в тыс.рублей

# %%
df['price_sq_m'] = df['price_sq_m'] / 1000

# %%
df['price_sq_m'].describe() # Цена за квадратный метр
# Out:
# count    23565.000000
# mean        99.405391
# std         50.389439
# min          0.111000
# 25%         76.566000
# 50%         95.000000
# 75%        114.213000
# max       1907.500000
# Name: price_sq_m, dtype: float64

# %%
# строим гистограмму на 30 корзин, со значениями min и max из describe()
price_sq_m = df['price_sq_m'].plot(
    kind='hist',
    histtype='step',
    range=(0.111, 1907.5),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Цена за м2',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Цена за м2, тыс.руб")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "price_sq_m"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Изучим подробнее пик гистограммы

# %%
# строим гистограмму на 30 корзин, со значениями min и 250 тыс.руб
price_sq_m = df['price_sq_m'].plot(
    kind='hist',
    histtype='step',
    range=(0.011100, 250),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Цена за м2',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Цена за м2, тыс.руб")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "price_sq_m"')
plt.show() # просмотр гистограммы

# %% [markdown]
# На гистограмме видно, что очень мало предложений квартир, стоимость которых менее 50 тыс.руб за м2. Это же относится и к квартирам, стоимость который за 1 м2 превышает 125 тыс.руб за м2. Средний ценовой диапазон за 1 м2 находится в пределах от 60 тыс.руб до 110 тыс.руб за 1 м2.

# %% [markdown]
# Обзор столбца "rooms" комнаты

# %%
df['rooms'].describe()
# Out:
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
# строим гистограмму на 19 корзин, со значениями min и max из describe()
df['rooms'].plot(
    kind='hist',
    histtype='step',
    range=(0, 19),
    bins=19,
    linewidth=3,
    alpha=0.7,
    label='Количество комнат',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Количество комнат")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "rooms"')
plt.show() # просмотр гистограммы

# %% [markdown]
# На гистограмме видно, что больше всего предложений относятся к квартирам с количеством комнат от 0 до 3 комнат. Резкий спад для квартир, где комнат более 4 и единичные предложения для квартир, где более 8 комнат.

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Можно задать число корзин равным максимальному количеству комнат.
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Исправила количество корзин. Спасибо за совет.
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Пожалуйста.
#
# </div>

# %% [markdown]
# Построим гистограммы, где будет отображаться высота потолков:

# %%
df['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.694123
# std          0.203614
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %%
# строим гистограмму на 10 корзин, со значениями min и max из describe()
df['ceiling_height'].plot(
    kind='hist',
    histtype='step',
    range=(2.5, 4),
    bins=10,
    linewidth=3,
    alpha=0.7,
    label='Высота потолков',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Высота потолков")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "ceiling_height"')
plt.show() # просмотр гистограммы

# %% [markdown]
# В основном предлагаются квартиры, высота потолков которых от 2,5 до 2,8 м. Квартиры  с более высокими потолками - относительная редкость.

# %% [markdown]
# Изучим время продажи квартиры. Но у нас есть квартиры, которые выставленны на продажу, но по факту еще не проданы. Поэтому будем рассматривать только те квартиры, по которым известно сколько дней длилась продажа.

# %%
df.query('days_exposition != 0')['days_exposition'].describe() #исключаем не проданные квартиры
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# строим гистограмму на 50 корзин, со значениями min и max из describe()
df.query('days_exposition != 0')['days_exposition'].plot(
    kind='hist',
    histtype='step',
    range=(1, 1580),
    bins=50,
    linewidth=3,
    alpha=0.7,
    label='Сколько дней было размещено объявление',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Количество дней")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "days_exposition"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Рассмотрим более подробно пик гистограммы, также среднее и медиану:

# %%
# строим гистограмму на 50 корзин, со значениями min и max из describe()
df.query('days_exposition != 0')['days_exposition'].plot(
    kind='hist',
    histtype='step',
    range=(1, 200),
    bins=50,
    linewidth=3,
    alpha=0.7,
    label='Сколько дней было размещено объявление',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Количество дней")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "days_exposition"')
plt.show()# просмотр гистограммы

print('Медиана: ', df.query('days_exposition != 0')['days_exposition'].median())
print('Среднее: ', round(df.query('days_exposition != 0')['days_exposition'].mean()))
# Out:
# Медиана:  95.0
# Среднее:  181

# %% [markdown]
# Самое высокое значение по количеству проданных квартир приходится на период от 45 до 95 дней. Это же подтвержает и медиана по столбцу. А вот среднее значение существенно отличается от медианы и гистограммы. Это связано с тем, что есть квартиры, срок продажи которых более года. Максимальное значение превышает 4 года. Быстрые продажи в течение первых 50 дней. Все, что продается более 400 дней - существенный срок.

# %% [markdown]
# Для достоверной оценки факторов, которые влияют на продажу квартир, необходимо убрать редкие и выбивающие значения из исследования.

# %%
#функция, которая удалит выбросы и аномалии по условию в 1,5 межквартильного размаха 
def anomaly_drop(df, column):
    Q1 = df[column].quantile(0.25)# опеределяет первый квартиль колонки
    Q3 = df[column].quantile(0.75)# опеределяет третий квартиль колонки
    IQR = Q3 - Q1 # межквартильный размах
    df_clear = df.loc[(df[column] < Q3 + 1.5*IQR) & (df[column] > Q1 - 1.5*IQR), column]
    return df_clear

# столбцы с выбросами
anomaly_list = ['last_price', 'total_area', 'kitchen_area', 'living_area', 'days_exposition', 'ceiling_height', 'rooms']
for column in anomaly_list:
    df[column] = anomaly_drop(df, column)

# удаляем строки с пропусками
df.dropna(inplace=True)

# проверка результата работы функции
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  17396.000000  17396.000000  17396.000000  17396.000000    17396.000000
# mean       9.736491      4.543052     50.836431      1.877156        2.626178
# std        5.523704      1.997425     16.305030      0.851439        0.080752
# min        0.000000      0.430000     12.000000      1.000000        2.500000
# 25%        6.000000      3.200000     38.000000      1.000000        2.550000
# 50%        9.000000      4.200000     47.000000      2.000000        2.650000
# 75%       14.000000      5.500000     60.700000      2.000000        2.650000
# max       39.000000     11.866860    114.200000      5.000000        2.850000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  17396.000000  17396.000000  17396.000000  17396.000000  17396.000000
# mean      11.054955     29.147343      6.027478      9.008288      0.610313
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17396 entries, 1 to 23564
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          17396 non-null  int64
#  1   last_price            17396 non-null  float64
#  2   total_area            17396 non-null  float64
#  3   first_day_exposition  17396 non-null  datetime64[ns]
#  4   rooms                 17396 non-null  float64
#  5   ceiling_height        17396 non-null  float64
#  6   floors_total          17396 non-null  int64
#  7   living_area           17396 non-null  float64
#  8   floor                 17396 non-null  int64
#  9   is_apartment          17396 non-null  bool
#  10  studio                17396 non-null  bool
#  11  open_plan             17396 non-null  bool
#  12  kitchen_area          17396 non-null  float64
#  13  balcony               17396 non-null  int64
# ...

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# А ведь ты не убрала целиком квартиры (строки), а удалила отдельные ячейки. И теперь опять пропуски в колонках, от которых избавлялись на первом этапе.
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Функцию подправила.
# </div>

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <b>Некоторые рекомендации 💡:</b>
#
# Стоит еще оценивать количество удаленных данных-выбросов и посчитать их процент. Удалять более 10% данных не стоит. Можно расширить интервал нормальных данных
#
#
# </div>

# %% [markdown]
# Изучим какие факторы больше всего влияют на стоимость квартиры. Для этого построим гистрограммы зависимости цены от площади, числа комнат, удаленности от центра, этажности и даты размещения объявления

# %% [markdown]
# Построим график зависимости цены от площади квартиры:

# %%
# график по сводной таблице по значениям столбцов Общая площадь и Цена 
(
    df.pivot_table(index='total_area', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от общей площади квартиры', grid=True, style='o', figsize=(10, 5))
) 
plt.xlabel("Площадь, м2")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от площади квартиры')
plt.show()

# %%
# коэффициент корреляции
print(f"Коэффициент корреляции: {df['total_area'].corr(df['last_price']):.2f}")
# Out:
# Коэффициент корреляции: 0.67

# %% [markdown]
# График и коэффициент корреляции показывают, что существует зависимость цены от общей площади квартиры. Однако нет строгой линейной зависимости этих двух параметров. Это говорит о том, что на конечную стоимость квартиры влияет не только ее общая площадь.

# %% [markdown]
# Рассмотрим, существует ли зависимость цены квартиры от количества комнат:

# %%
# график по сводной таблице по значениям столбцов Количество комнат и Цена 
(
    df.pivot_table(index='rooms', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от количества комнат', grid=True, style='o-', figsize=(10, 5))
)
plt.xlabel("Количество комнат")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от количества комнат')
plt.ylim([0, 7])
plt.show()

# %%
print(f"Коэффициент корреляции: {df['rooms'].corr(df['last_price']):.2f}")
# Out:
# Коэффициент корреляции: 0.41

# %% [markdown]
# Зависимость есть: количество комнат влияет на итоговую цену квартиры. Разница в цене за квартиры, где количество комнат не больше 3, более выражена, чем для квартир с количеством комнат больше 3. Но это только один из показателей.

# %% [markdown]
# Определим взаимосвязь между удаленностью от центра и конечной ценой квартиры

# %%
# график по сводной таблице по значениям столбцов Расстояние до центра и Цена 
(
    df.pivot_table(index='city_centers_nearest', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от расстояния до центра', grid=True, style='o', figsize=(10, 5))
)
plt.xlabel("Расстояние от центра, м")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от расстояния до центра')
plt.show()

# %%
print(f"Коэффициент корреляции: {df['city_centers_nearest'].corr(df['last_price']):.2f}")
# Out:
# Коэффициент корреляции: 0.18

# %% [markdown]
# Чем ближе квартира к центру, тем выше ее стоимость. Вполне ожидаемо.

# %% [markdown]
# Рассмотрим как высота потолков влияет на цену квартиры

# %%
# график по сводной таблице по значениям столбцов Высота потолков и Цена 
(
    df.pivot_table(index='ceiling_height', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от высоты потолков', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([0, 8])
plt.xlabel("Высота потолков, м")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от высоты потолков')
plt.show()

# %%
print(f"Коэффициент корреляции: {df['ceiling_height'].corr(df['last_price']):.2f}")
# Out:
# Коэффициент корреляции: 0.23

# %% [markdown]
# В основном квартиры, где высота потолков 2,61 м и потолки высотой 2,73 м по цене выше. Цена за квартиры с более высокими потолками выше, чем у квартир со стандартной высотой.

# %% [markdown]
# Построим график зависимости между итоговой ценой и тем, на каком этаже находится квартира.

# %%
# график по сводной таблице по значениям столбцов Категория этажа и Цена 
(
    df.pivot_table(index='floor_category', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от этажа квартиры', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([0, 5])
plt.xlabel("Категория этажа")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены этажа квартиры')
plt.show()

# %% [markdown]
# Самые дорогие этажи те, которые относятся к категории "Другой". Самые дешевые квартиры на первом этаже. При этом разница по цене между первым  и последним этажом незначительна, по сравнению с категорией "Другой".

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Такой график очень обманчив, кажется, что средняя цена упала в разы, практически до 0, а потом в несколько раз увеличилась. Хотя колебания не больше 10%. Лучше начало оси y начинать с 0. Тогда визуально можно оценить, на сколько менялась динамика цены. Это можно сделать, добавив в метод plot параметр ylim=([0,....]).
#
# К графикам зависимости от даты объявления тот же комментарий.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Внесла правки.
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошо.
#
# </div>

# %% [markdown]
# Рассмотрим как день, месяц и год публикации объявлений влияют на исследование

# %%
# график по сводной таблице по значениям столбцов День недели публикации и Цена 
(
    df.pivot_table(index='weekday_exposition', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от дня публикации', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([4, 5])
plt.xlabel("День недели")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от дня публикации')
plt.show()

# %% [markdown]
# В будние дни стоимость немного выше, чем в выходные. Самая низкая стоимость приходится на субботу. А максимум на среду.

# %%
# график по сводной таблице по значениям столбцов Месяц публикации и Цена 
(
    df.pivot_table(index='montn_exposition', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от месяца публикации', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([4, 5])
plt.xlabel("Месяц публикации")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от месяца публикации')
plt.show()

# %% [markdown]
# Спад публикаций приходится на конец года. Максимум приходится на апрель. Самые дешевые квартиры в июне. Постепенный рост с середины лета - к концу осени (ноябрь). Возможно это связано с сезонностью стройки (I и III кварталы года). Либо с возможностью людей приобретать новое жилье. Так же нельзя исключать "жизненный" цикл покупателей. Январь пора новогодний праздников. Май, июнь - траты на отпуск, выпускные, и т.д. А вот свадьбы чаще приходятся на февраль, март и осенние месяцы.

# %%
# график по сводной таблице по значениям столбцов Год публикации и Цена 
(
    df.pivot_table(index='year_exposition', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от года публикации', grid=True, style='o-', figsize=(10, 5))
)
#plt.ylim([4, 5])
plt.xlabel("Год публикации")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от года публикации')
plt.show()

# %% [markdown]
# Максимум цены наблюдался в 2014 году. Резкое падение цен на недвижимость с 2014 по 2016 год. В 2016-2017 цены держались в пределах 4,5 млн.руб. Однако начиная с 2018 года наблюдается рост цен. Возможно это связано с улучшением в целом экономической ситуации населения.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <font color='red'><b>На доработку ❌:</b>  </font>
#
# Комментарий ко всем трем графикам анализа зависимости от даты объявления. Надо оценить зависимость не от количества объявлений, а от средней стоимости. Т.е. надо поменять агрегацию.
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Внесла правки.
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Молодец.
#
# </div>

# %% [markdown]
# Сведем все ранее построенные графики вместе, используя матрицу диаграмм рассеивания. Изучим матрицу диаграмм рассеивания для показателей площадь, цена, число комнат и высота потолков. Опеределим коэффициент корреляции для каждой пары значений.

# %%
# матрица диаграмм рассеивания для показателей цена, общая площадь и жилая площадь
df_matrix = df.filter(['last_price', 'total_area', 'living_area'], axis=1)
pd.plotting.scatter_matrix(df_matrix, figsize=(9, 9))
plt.show()

print(df_matrix.corr()) # коэффициент корреляции
# Out:
#              last_price  total_area  living_area
# last_price     1.000000    0.666533     0.516532
# total_area     0.666533    1.000000     0.899836
# living_area    0.516532    0.899836     1.000000

# %% [markdown]
# На матрице и по коэффициенту корреляции видно, что самая большая зависимость между показателями это соотношение общей и жилой площади (что в принципе логично). Корреляция остальных показателей есть, но не такая явная. На соотношение цены и площадей будут влиять и другие (сторонние или дополнительные) показатели.

# %%
# матрица диаграмм рассеивания для показателей цена, количество комнат и высота потолков
df_matrix = df.filter(['last_price', 'rooms', 'ceiling_height'], axis=1)
pd.plotting.scatter_matrix(df_matrix, figsize=(9, 9))
plt.show()

print(df_matrix.corr()) # коэффициент корреляции
# Out:
#                 last_price     rooms  ceiling_height
# last_price        1.000000  0.406075        0.230823
# rooms             0.406075  1.000000       -0.105197
# ceiling_height    0.230823 -0.105197        1.000000

# %% [markdown]
# Высота потолков практически никак не влияет на цену. Количество комнат и цена - показатели связанные между собой. Но нельзя однозначно утверждать, что уменьшение количества комнат сильно снизит конечную стоимость.

# %% [markdown]
# Выберем 10 населенных пунктов с наибольшим числом объявлений и рассчитаем среднюю цену за квадратный метр в этих населенных пунктах:

# %%
# топ 10 населенных пунктов
top_10 = df.pivot_table(index='locality_name', values='price_sq_m', aggfunc = ['count', 'mean'])
top_10.columns = ['count', 'mean']
top_10.sort_values(by='count', ascending=False, inplace=True)
top_10 = top_10.head(10)

display(top_10)
# Out:
#                    count        mean
# locality_name
# Санкт-Петербург    10726  104.384030
# посёлок Мурино       440   85.398266
# посёлок Шушары       400   78.191207
# Всеволожск           332   66.824024
# Колпино              294   75.267510
# посёлок Парголово    291   90.497598
# Пушкин               268   99.179414
# Гатчина              257   68.403763
# деревня Кудрово      225   93.016662
# Выборг               190   57.306226

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Верно.

# %% [markdown]
# Больше всего объявлений в Санкт-Петербурге. Замыкает тройку лидеров поселки. Возможно это поселки рядом с Санкт-Петербургом и поэтому пользуется особым спросом. Меньше всего объявлений - в Выборге.

# %% [markdown]
# Определим из этого списка населенных пунктов где самая высокая и низкая средная стоимость жилья за 1 м2:

# %%
# самая низкая и высокая стоимость жилья (по среднему значению стоимости за 1 м2)
top_10.sort_values(by='mean', ascending=False, inplace=True)
display(top_10)
# Out:
#                    count        mean
# locality_name
# Санкт-Петербург    10726  104.384030
# Пушкин               268   99.179414
# деревня Кудрово      225   93.016662
# посёлок Парголово    291   90.497598
# посёлок Мурино       440   85.398266
# посёлок Шушары       400   78.191207
# Колпино              294   75.267510
# Гатчина              257   68.403763
# Всеволожск           332   66.824024
# Выборг               190   57.306226

# %% [markdown]
# Вполне ожидаемо, что самая высокая стоимость будет в Санкт-Петербурге. Самая низкая средняя стоимость 1 м2 жилья в Выборге.

# %% [markdown]
# Определим границу центральной зоны Санкт-Петербурга

# %%
df['dist_center_km'] = df['city_centers_nearest']/1000 # создаем столбец и округяем до целых значений
df['dist_center_km'] = df['dist_center_km'].astype('int')
df_center = df.query('locality_name == "Санкт-Петербург"')

(df_center
     .pivot_table(index='dist_center_km', values='last_price', aggfunc = 'mean')
     .plot(title='Зависимость цены от расстояния до центра', grid=True, style='o-', figsize=(10, 5))
)
plt.xlabel("Расстояние до центра города, км")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от расстояния до центра Санкт-Петербурга')
plt.show()

# %% [markdown]
# На графике видно, что чем дальше от центра, тем средняя стоимость квартиры становиться меньше. Расстояние до 7-8 км можно определить как центр города. Так же наблюдается пик в радиусе 20 км от центра города. Возможно это "спальные" районы.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Согласна. 7 км вполне приемлемая граница для зоны центра Санкт-Петербурга.
#
# </div>

# %% [markdown]
# Определим и изучим параметры квартир в центре Санкт-Петербурга

# %%
df_SP = df.query('locality_name == "Санкт-Петербург" and dist_center_km <= 8')

# %%
df_SP['total_area'].describe() # изучим информацию по столбцу "total_area"
# Out:
# count    1538.000000
# mean       57.354844
# std        19.544701
# min        12.000000
# 25%        42.700000
# 50%        55.200000
# 75%        70.000000
# max       114.200000
# Name: total_area, dtype: float64

# %% [markdown]
# В таблице представлена информация на 1538 объекта недвижимости.  Среднее значение площади квартир в центре около 57 м2. Встречаются квартиры площадью 12 м2. Возможно это студия. Для студий характерный очень малые размеры площади. Максимальная площадь 114 м2.

# %% [markdown]
# Построим гистограмму для столбца "total_area":

# %%
# строим гистограмму на 50 корзин, со значениями min и max из describe()
df_SP['total_area'].plot(
    kind='hist',
    histtype='step',
    range=(12, 114),
    bins=50,
    linewidth=3,
    alpha=0.7,
    label='Площадь квартиры, м2',
    grid=True,
    legend=True,
    figsize=(10, 5)    
) 
plt.xlabel("Площадь квартиры")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "total_area"')
plt.show() # просмотр гистограммы

# %% [markdown]
# На гистограмме наблюдаются, что  в основном продаются квартиры с площадью от 30 до 75 м2. Пик гистограммы приходится на значение около площади в 45 м2. Видно, что в центре города предпочитают небольшие по площади квартиры: от 30 до 50 м2. Определим, какие квартиры предпочитают в центре Санкт-Петербурга

# %%
df_SP.groupby('rooms')['rooms'].count()
# Out:
# rooms
# 1.0    481
# 2.0    600
# 3.0    375
# 4.0     78
# 5.0      4
# Name: rooms, dtype: int64

# %% [markdown]
# На первом месте квартиры с 2-мя комнатами, на втором 1-однокомнатные и замыкают 3-х комнатные. Квартиры с большим числом комнат - редкость.

# %% [markdown]
# Рассмотрим гистограммы из категории цена: "last_price" (цена на момент снятия публикации) и "price_sq_m" (цена за м2)

# %%
df_SP['last_price'].describe()
# Out:
# count    1538.000000
# mean        6.604713
# std         2.235114
# min         1.686000
# 25%         4.800000
# 50%         6.450000
# 75%         8.200000
# max        11.866860
# Name: last_price, dtype: float64

# %% [markdown]
# Средняя стоимость квартиры 6,6 млн.руб. Минимальная около 1,68 млн. руб, максимальная 11,87 млн.руб. Очень большой диапазон цен, на это указывает и стандартное отклонение в 2,23.

# %% [markdown]
# Построим гистограмму для столбца df_SP['last_price']

# %%
# строим гистограмму на 30 корзин, со значениями min и max из describe()
df_SP['last_price'].plot(
    kind='hist',
    histtype='step',
    range=(1.686, 11.86686),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Цена на момент снятия публикации',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Цена на момент снятия публикации")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "last_price"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Основной ценовой диапазон от 5 до 9 млн.руб. Начиная со стоимости 10 млн.руб предложений становиться меньше.

# %% [markdown]
# Изучим данные столбца "price_sq_m".

# %%
df_SP['price_sq_m'].describe() # Цена за квадратный метр
# Out:
# count    1538.000000
# mean      118.229012
# std        28.414407
# min        26.250000
# 25%        98.296250
# 50%       113.657000
# 75%       134.395750
# max       292.307000
# Name: price_sq_m, dtype: float64

# %%
# строим гистограмму на 30 корзин, со значениями min и max из describe()
price_sq_m = df['price_sq_m'].plot(
    kind='hist',
    histtype='step',
    range=(26.25, 292.307),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Цена за м2',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Цена за м2, тыс.руб")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "price_sq_m"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Большинство квартир, которые предлагаются в центре Санкт-Петербурга имеют цену за 1 м2 от 55 тыс. до 130 тыс. руб. Более дорогие квартиры, где стоимость квадратного метра более 150 тыс. руб. являются редкими. Так же очень редки предложения квартир, стоимость которых за 1 м2 менее 30 тыс.руб.

# %% [markdown]
# Обзор столбца "rooms" комнаты

# %%
df_SP['rooms'].describe()
# Out:
# count    1538.000000
# mean        2.040312
# std         0.884148
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: rooms, dtype: float64

# %%
# строим гистограмму на 5 корзин, со значениями min и max из describe()
df['rooms'].plot(
    kind='hist',
    histtype='step',
    range=(1, 5),
    bins=5,
    linewidth=3,
    alpha=0.7,
    label='Количество комнат',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Количество комнат")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "rooms"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Как уже определили раньше, наибольшее количество предложений связано с 1 и 2-х комнатными квартирами. Квартир с числом комнат больше 3 - единичные предложения.

# %% [markdown]
# Построим гистограммы, где будет отображаться высота потолков:

# %%
df_SP['ceiling_height'].describe()
# Out:
# count    1538.000000
# mean        2.651222
# std         0.079007
# min         2.500000
# 25%         2.650000
# 50%         2.650000
# 75%         2.650000
# max         2.850000
# Name: ceiling_height, dtype: float64

# %%
# строим гистограмму на 10 корзин, со значениями min и max из describe()
df['ceiling_height'].plot(
    kind='hist',
    histtype='step',
    range=(2.5, 2.85),
    bins=10,
    linewidth=3,
    alpha=0.7,
    label='Высота потолков',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Высота потолков")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "ceiling_height"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Наибольшее количество предложений - это квартиры, где высота потолков выше стандарта - 2,65 м.

# %% [markdown]
# Изучим время продажи квартиры. Но у нас есть квартиры, которые выставленны на продажу, но по факту еще не проданы. Поэтому будем рассматривать только те квартиры, по которым известно сколько дней длилась продажа.

# %%
df_SP.query('days_exposition != 0')['days_exposition'].describe() #исключаем не проданные квартиры
# Out:
# count    1384.000000
# mean      119.217486
# std       111.265414
# min         3.000000
# 25%        35.000000
# 50%        80.000000
# 75%       171.000000
# max       460.000000
# Name: days_exposition, dtype: float64

# %%
# строим гистограмму на 30 корзин, со значениями min и max из describe()
df.query('days_exposition != 0')['days_exposition'].plot(
    kind='hist',
    histtype='step',
    range=(3, 460),
    bins=30,
    linewidth=3,
    alpha=0.7,
    label='Сколько дней было размещено объявление',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Количество дней")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "days_exposition"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Самые высокие показатели по количеству дней продажи - это до 80 дней. Причем очень много быстрых продаж - до 40 дней. Возможно это связано с тем, что многие хотят жить в центре города, поэтому стараются как можно быстрее оформить покупку. Продажи более 200 дней - уже редки.

# %% [markdown]
# Построим гистрограмму по этажам:

# %%
df_SP['floor'].describe()
# Out:
# count    1538.000000
# mean        4.823797
# std         3.622137
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        24.000000
# Name: floor, dtype: float64

# %%
# строим гистограмму на 24 корзин, со значениями min и max из describe()
df_SP['floor'].plot(
    kind='hist',
    histtype='step',
    range=(1, 24),
    bins=24,
    linewidth=3,
    alpha=0.7,
    label='Этаж',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Этаж")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "floor"')
plt.show() # просмотр гистограммы

# %% [markdown]
# Наибольшее количество квартир находится со 2 по 6 этаж. Квартиры, которые находятся выше 9т этажа встречаются гораздо реже.

# %% [markdown]
# Изучим предложения по значению столбца "dist_center_km" (расстояние до центра города)

# %%
df_SP['dist_center_km'].describe()
# Out:
# count    1538.000000
# mean        5.326398
# std         2.170985
# min         0.000000
# 25%         4.000000
# 50%         5.000000
# 75%         7.000000
# max         8.000000
# Name: dist_center_km, dtype: float64

# %%
# строим гистограмму на 10 корзин, со значениями min и max из describe()
df_SP['dist_center_km'].plot(
    kind='hist',
    histtype='step',
    range=(0, 8),
    bins=24,
    linewidth=3,
    alpha=0.7,
    label='Этаж',
    grid=True,
    legend=True,
    figsize=(10, 5)
) 
plt.xlabel("Этаж")
plt.ylabel("Количество объявлений")
plt.title('Обзор столбца "floor"')
plt.show() # просмотр гистограммы

# %% [markdown]
# В самом центре города - предложений гораздо меньше, чем на расстоянии 8 км от условного центра. Среднее растояние - 4-5 км от центра.

# %% [markdown]
#  <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку ❌:</b>
#
# По заданию: проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.
#
# Здесь у тебя сразу идет переход к анализу зависимостей факторов на стоимость. А этап анализа параметров пропущен . Добавь этот шаг, сделай выводы. Можно провести анализ параметров с помощью гистограмм, как ты это делала на общей выборке
#
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Добавила этап анализа параметров площади, цены, число комнат, высоту потолков, этаж и расстояние до центра по Санкт-Петербургу.
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Отлично. Молодец.
#
# </div>

# %% [markdown]
# Проведем анализ зависимостей факторов на стоимость квартиры.

# %% [markdown]
# Соотношение цены и площади квартиры

# %%
# Цена и площадь квартиры в цетре Санкт-Петербурга
(
    df_SP.pivot_table(index='total_area', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от общей площади квартиры', grid=True, style='o', figsize=(10, 5))
) 
plt.xlabel("Площадь, м2")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от площади квартиры')
plt.show()
print('Медиана площади: ', df_SP.groupby('last_price')['total_area'].sum().median())
print('Медиана цены: ', df_SP.groupby('total_area')['last_price'].sum().median())

# коэффициент корреляции 
print(f"Коэффициент корреляции по общей таблице: {df['total_area'].corr(df['last_price']):.2f}") 
print(f"Коэффициент корреляции по Санкт-Петербургу: {df_SP['total_area'].corr(df_SP['last_price']):.2f}")
# Out:
# Медиана площади:  72.0
# Медиана цены:  10.2486
# Коэффициент корреляции по общей таблице: 0.67
# Коэффициент корреляции по Санкт-Петербургу: 0.75

# %% [markdown]
# График и коэффициент корреляции показывают, что существует зависимость цены от общей площади квартиры. Чем больше площадь квартиры, тем больше ее цена. Квартиры с площадью от 30 до 50 м2 имеют меньший диапазон по разбросу итоговой стоимости. Есть очень дорогие квартиры с малой площадью. Квартиры с площадью от 60 м2 имеют больший разброс по цене. Есть очень дешевые квартиры с площадью около 80 м2, а также очень дорогие, порядка 12 млн.руб.
# Средний показатель - это квартира 72 м2 по средней цене около 10 млн.руб.

# %% [markdown]
# Соотношение цены и количества комнат

# %%
# Цена и количество комнат в цетре Санкт-Петербурга 
(
    df_SP.pivot_table(index='rooms', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от количества комнат', grid=True, style='o-', figsize=(10, 5))
)
plt.xlabel("Количество комнат")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от количества комнат')
plt.ylim([0, 10])
plt.show()
print('Медиана по количеству комнат: ', df_SP.groupby('last_price')['rooms'].sum().median())

# коэффициент корреляции 
print(f"Коэффициент корреляции по общей таблицы: {df['rooms'].corr(df['last_price']):.3f}")
print(f"Коэффициент корреляции по Санкт-Петербургу: {df_SP['rooms'].corr(df_SP['last_price']):.3f}")
# Out:
# Медиана по количеству комнат:  3.0
# Коэффициент корреляции по общей таблицы: 0.406
# Коэффициент корреляции по Санкт-Петербургу: 0.463

# %% [markdown]
# Чем больше комнат, тем выше стоимость квартиры. Это немного отличается от показателей по общей таблицы, где разница между трехкомнатными и квартирами с большим количеством комнат меньше.

# %% [markdown]
# Соотношение между ценой и расстоянием до условного центра города

# %%
# Цена и расстояние до цетра Санкт-Петербурга  
(
    df_SP.pivot_table(index='city_centers_nearest', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от расстояния до центра', grid=True, style='o', figsize=(10, 5))
)
plt.xlabel("Расстояние от центра, м")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от расстояния до центра')
plt.show()

print(f"Коэффициент корреляции по общей таблицы: {df['city_centers_nearest'].corr(df['last_price']):.3f}")
print(f"Коэффициент корреляции по Санкт-Петербургу: {df_SP['city_centers_nearest'].corr(df_SP['last_price']):.3f}")
# Out:
# Коэффициент корреляции по общей таблицы: 0.176
# Коэффициент корреляции по Санкт-Петербургу: -0.239

# %% [markdown]
# Близость к центру города влияет на итоговую стоимость квартиры. Однако не в самом центре, а на расстоянии 4-6 км от него. Здесь наблюдается более плотное расположение показателей.

# %% [markdown]
# Соотношение цены и высоты потолков

# %%
# Цена и высота потолков в центре Санкт-Петербурга 
(
    df_SP.pivot_table(index='ceiling_height', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от высоты потолков', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([0, 10])
plt.xlabel("Высота потолков, м")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от высоты потолков')
plt.show()

print(f"Коэффициент корреляции по общей таблицы: {df['ceiling_height'].corr(df['last_price']):.3f}")
print(f"Коэффициент корреляции по Санкт-Петербургу: {df_SP['ceiling_height'].corr(df_SP['last_price']):.3f}")
# Out:
# Коэффициент корреляции по общей таблицы: 0.231
# Коэффициент корреляции по Санкт-Петербургу: 0.269

# %% [markdown]
# Здесь практически нет особых отличий от графика общей таблицы. Два основных пика: 2,64 м и 2,73 м. Предпочтительнее квартиры с высотой потолков выше 2,6 м

# %% [markdown]
# Соотношение цены и категории этажа

# %%
# Цена и этаж в центре Санкт-Петербурга
(
    df_SP.pivot_table(index='floor_category', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от этажа квартиры', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([5, 7])
plt.xlabel("Категория этажа")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены этажа квартиры')
plt.show()

# %% [markdown]
# Также как и на графике общей таблице, самые дешевые квартиры на первом этаже. А вот существенной разницы между последними и другими этажами нет.

# %% [markdown]
# Рассмотрим как день, месяц и год публикации объявлений влияют на исследование

# %%
# график по таблице Санкт-Петербург по значениям столбцов День недели публикации и Цена 
(
    df_SP.pivot_table(index='weekday_exposition', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от дня публикации', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([5, 8])
plt.xlabel("День недели")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от дня публикации')
plt.show()

# %% [markdown]
# В будние дни пик приходится на субботу. В отличие от основной таблицы максимум приходится на воскресенье.

# %%
# график по сводной таблице по значениям столбцов Месяц публикации и Цена 
(
    df_SP.pivot_table(index='montn_exposition', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от месяца публикации', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([5, 8])
plt.xlabel("Месяц публикации")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от месяца публикации')
plt.show()

# %% [markdown]
# График существенно отличается от графика основной таблицы. Единственное совпадение - минимум приходится также на июнь. А вот два максимума на сентябрь и ноябрь. Также есть второй минимальный участок на ноябре.

# %%
# график по сводной таблице по значениям столбцов Год публикации и Цена 
(
    df_SP.pivot_table(index='year_exposition', values='last_price', aggfunc = 'mean')
    .plot(title='Зависимость цены от года публикации', grid=True, style='o-', figsize=(10, 5))
)
plt.ylim([5, 8])
plt.xlabel("Год публикации")
plt.ylabel("Цена, млн.руб")
plt.title('Зависимость цены от года публикации')
plt.show()

# %% [markdown]
# Отличия от основной таблицы в том, что не смотря на снижение цен, не наблюдается существенная разница. Это говорит в пользу того, что квартиры в центре всегда будут привлекательны, вне зависимости от цен на основную недвижимость.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <font color='red'><b>На доработку ❌:</b>  </font>
#
# Такое же замечание, как и на общей выборке. В агрегации должна стоять mean, а не count.
#
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Изменения внесла. После изменения функции пришлось полностью пересмотреть графики и сделать повторный анализ.
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошо.
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# На основнии полученных данных была выполнена предобработка: исправлены типы данных на корректные, поиск и замена пропусков, дубликаты, аномалии и выбросы.
#
# Проведен исследовательский анализ данных с построением гистограмм и графиков.
#
# Средний срок продажи квартиры составляет 95 дней. Все что меньше 50 дней, можно считать быстрыми продажами. Если дольше 220-230 дней - это долго. Есть также супер быстрые (за несколько дней) и супер долгие продажи (более 10 месяцев).
#
# Публикация объявлений явно связана с "жизненным" циклом людей. Подъем в будние и спад в выходные. А также сезонность в течение года. Начало весны и конец года. Разница между общей таблицей и данным по Санкт-Петербургу не существенна.
#
# Основные факторы, влияющие на стоимость квартиры:
# Из всех показателей площадей, наибольшее значение  - это общая площадь квартиры и цена за 1м2.  Площадь, цена за 1м2 и расстояние от центра города влияют больше, чем количество комнат и высота потолков.
# Первый этаж значительно дешевле остальных. А в центре города эта разница еще больше.
#
# Определи топ-10 населенных пунктов, в которых самый дорогой квадратный метр. Из этого списка лидером является Санкт-Петербург и замыкает Выборг.
#
# Анализа данных по общей таблице следующий. "Типичная" недвижимость это 1-2-комнатная квартира, площадью 45-60 м2 на средних этажах. Стоимость около 5 млн.руб. Цена за квадратный метр - от 50 до 100 тыс.руб. На расстоянии 20 км от центра города.
#
# Анализ данных по центру Санкт-Петербурга:
# Был определен "условный" центр города. На расстоянии 2 км от центра предложений чуть меньше, чем на расстоянии от 4 км. Квартиры в центре дороже чем в других районах города. Но есть еще одна граница на расстоянии в 20км от центра, в которой стоимость квартиры выше, чем по другим районам. Возможно, это "спальные" районы.
#
# Срез по центру Санкт-Петербурга показал, что средняя квартира:
# это 1-2- комнатная квартира, площадь которой от 30 до 60 м2. На расстоянии от центра города в пределах 4-8 км. Предпочтительно на средних этажах (2-7 этаж). Средняя стоимость 6-8 млн.руб. Стоимость квадратного метра -  от 60 до 110 тыс.руб.
#
# Так же надо отметить, что цена на недвижимость в центре города менее подвержена колебаниям в течение нескольких лет, чем типичная квартира по основной таблице.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Цель анализа состояла в том, чтобы определить параметры типичной квартиры, чтобы построить автоматизированную систему для отслеживания аномалий и мошеннической деятельности. Общий вывод должен содержать эту информацию. Поправь, пожалуйста, вывод согласно цели анализа.
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Внесла изменение в общий вывод по исследованию
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Основные моменты в выводах учтены, теперь общий вывод отвечает на поставленный в задаче вопрос.
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Проделана большая работа, и видно твое внимательное отношение к оформлению анализа. Ты молодец! Все ключевые этапы работы над проектом выполнены, код логичен и понятен, комментарии и выводы написаны, так что в целом справиться с задачей тебе удалось. Возле моментов, на которые стоит обратить внимание, я оставила комментарии.
#
# **Отдельно хочу отметить положительные моменты в твоей работе:**
#
# * Очень хорошо расписаны комментарии и план решения на каждом этапе проекта, становится понятен твой ход мысли. В будущем при необходимости вернуться к проекту, тебе тоже будет легко вспомнить логику анализа.
# * На всех этапах тобой предложены интересные решения и методы для их реализации.
# * Ты активно и грамотно используешь визуализацию. Это здорово, т.к. помогает быстро считать информацию получателю отчета.* Ты грамотно делаешь выводы, на основе полученной информации.
#
#
# **Осталась пара моментов, требующих внимания:**
#
# * Пересмотри обработку пропусков по признаку days_exposition.
# * Скорректируй анализ зависимости стоимости квартиры от даты выставления объявления.
# * Добавь анализ параметров квартир в центре.
# * И обязательно поправь итоговый вывод, после учета всех комментариев.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Спасибо за доработку. Проект принят. Желаю удачи в дальнейшем обучении.
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
